# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
import os
import mlflow
import mlflow.sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, roc_curve, confusion_matrix, ConfusionMatrixDisplay
)
from xgboost import XGBClassifier

# %%
def run_mlflow(run_name="Entrenamiento_XGBoost"):
    with mlflow.start_run(run_name=run_name) as run:
        # IDs de referencia
        experimentID = run.info.experiment_id
        runID = run.info.run_id

        # 1. Cargar datos
        train = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vS60HQztm8Bh9VS0LiK9Uhr9llcpJnxpefPrNKMC7TjWY3PslbhPBLDuc2Pf2t-yzwO6nXOPGpHSdr-/pub?output=csv")
        test = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vTuZODZ6QTsYqzReqNm9arsBIc-tusb063SPYCB6riVdpbezq0lZs3mWDIvYVOodjvM4zPe-QekUS5Q/pub?output=csv")

        y = train['Subscription']
        X = train.drop(columns=['Subscription'])

        # 2. Identificar tipos de variables
        num_features = X.select_dtypes(include=[np.number]).columns.tolist()
        cat_features = X.select_dtypes(include='object').columns.tolist()

        # 3. Preprocesamiento
        numeric_transformer = Pipeline([
            ('imputer', SimpleImputer(strategy='median')),
            ('scaler', StandardScaler())
        ])

        categorical_transformer = Pipeline([
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('encoder', OneHotEncoder(handle_unknown='ignore'))
        ])

        preprocessor = ColumnTransformer([
            ('num', numeric_transformer, num_features),
            ('cat', categorical_transformer, cat_features)
        ])

        # 4. Pipeline con modelo
        clf_pipeline = Pipeline([
            ('preprocessor', preprocessor),
            ('classifier', XGBClassifier(
                use_label_encoder=False,
                eval_metric='logloss',
                random_state=42
            ))
        ])

        # 5. División de datos
        X_train, X_valid, y_train, y_valid = train_test_split(
            X, y, test_size=0.3, stratify=y, random_state=42
        )

        # 6. Búsqueda de hiperparámetros
        param_grid = {
            'classifier__n_estimators': [50, 150, 250],
            'classifier__max_depth': [2, 4, 6],
            'classifier__learning_rate': [0.05, 0.1, 0.25],
            'classifier__subsample': [0.6, 0.8, 1.0],
            'classifier__colsample_bytree': [0.6, 0.8, 1.0]
        }

        random_search = RandomizedSearchCV(
            clf_pipeline,
            param_distributions=param_grid,
            n_iter=20,
            scoring='roc_auc',
            cv=5,
            verbose=1,
            random_state=42
        )

        random_search.fit(X_train, y_train)
        best_model = random_search.best_estimator_

        # 7. Log de parámetros y métricas
        mlflow.log_params(random_search.best_params_)

        y_pred_proba = best_model.predict_proba(X_valid)[:, 1]
        y_pred = best_model.predict(X_valid)

        metrics = {
            "AUC_ROC": roc_auc_score(y_valid, y_pred_proba),
            "Accuracy": accuracy_score(y_valid, y_pred),
            "Precision": precision_score(y_valid, y_pred),
            "Recall": recall_score(y_valid, y_pred),
            "F1": f1_score(y_valid, y_pred)
        }

        mlflow.log_metrics(metrics)

        # 8. Importancia de variables
        importances = best_model.named_steps['classifier'].feature_importances_
        feature_names = best_model.named_steps['preprocessor'].get_feature_names_out()
        feat_importance = pd.Series(importances, index=feature_names).sort_values(ascending=False)

        plt.figure(figsize=(8,6))
        feat_importance.head(10).plot(kind='barh', color='skyblue')
        plt.title("Top 10 variables más importantes")
        plt.gca().invert_yaxis()
        plt.tight_layout()
        plt.savefig("feature_importance.png")
        mlflow.log_artifact("feature_importance.png")
        plt.close()

        # 9. Curva ROC
        fpr, tpr, _ = roc_curve(y_valid, y_pred_proba)
        plt.plot(fpr, tpr, label=f"AUC = {metrics['AUC_ROC']:.4f}")
        plt.plot([0, 1], [0, 1], 'k--')
        plt.xlabel('Tasa Falsos Positivos')
        plt.ylabel('Tasa Verdaderos Positivos')
        plt.title('Curva ROC')
        plt.legend()
        plt.grid(True)
        plt.savefig("roc_curve.png")
        mlflow.log_artifact("roc_curve.png")
        plt.close()

        # 10. Matriz de confusión
        cm = confusion_matrix(y_valid, y_pred)
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=best_model.classes_)
        disp.plot(cmap='Blues')
        plt.title('Matriz de Confusión')
        plt.savefig("confusion_matrix.png")
        mlflow.log_artifact("confusion_matrix.png")
        plt.close()

        # 11. Guardar modelo completo (pipeline)
        mlflow.sklearn.log_model(
            best_model,
            artifact_path="modelo_xgb_pipeline",
            registered_model_name="Modelo_ClasificacionV2"
        )

        print(f"\nMLflow Run completado con run_id {runID} y experiment_id {experimentID}")
        return experimentID, runID

# %%
if __name__ == "__main__":
    expID, runID = run_mlflow()
    print(f"Ejecutado correctamente en experimento ID: {expID}")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[23], line 2
#       1 if __name__ == "__main__":
# ----> 2     expID, runID = run_mlflow()
#       3     print(f"Ejecutado correctamente en experimento ID: {expID}")
#
# Cell In[21], line 2, in run_mlflow(run_name)
#       1 def run_mlflow(run_name="Entrenamiento_XGBoost"):
# ----> 2     with mlflow.start_run(run_name=run_name) as run:
#       3         # IDs de referencia
#       4         experimentID = run.info.experiment_id
#       5         runID = run.info.run_id
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/tracking/fluent.py:390, in start_run(run_id, experiment_id, run_name, nested, parent_run_id, tags, description, log_system_metrics)
#     382 if len(active_run_stack) > 0 and not nested:
#     383     raise Exception(
#     384         (
#     385             "Run with UUID {} is already active. To start a new run, first end the "
#    (...)
#     388         ).format(active_run_stack[0].info.run_id)
#     389     )
# --> 390 client = MlflowClient()
#     391 if run_id:
#     392     existing_run_id = run_id
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/tracking/client.py:218, in MlflowClient.__init__(self, tracking_uri, registry_uri)
#     216 final_tracking_uri = utils._resolve_tracking_uri(tracking_uri)
#     217 self._registry_uri = registry_utils._resolve_registry_uri(registry_uri, tracking_uri)
# --> 218 self._tracking_client = TrackingServiceClient(final_tracking_uri)
#     219 self._tracing_client = TracingClient(tracking_uri)
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/tracking/_tracking_service/client.py:96, in TrackingServiceClient.__init__(self, tracking_uri)
#      91 self.tracking_uri = tracking_uri
#      92 # NB: Fetch the tracking store (`self.store`) upon client initialization to ensure that
#      93 # the tracking URI is valid and the store can be properly resolved. We define `store` as a
#      94 # property method to ensure that the client is serializable, even if the store is not
#      95 # self.store
# ---> 96 self.store
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/tracking/_tracking_service/client.py:100, in TrackingServiceClient.store(self)
#      98 @property
#      99 def store(self):
# --> 100     return utils._get_store(self.tracking_uri)
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/tracking/_tracking_service/utils.py:216, in _get_store(store_uri, artifact_uri)
#     215 def _get_store(store_uri=None, artifact_uri=None):
# --> 216     return _tracking_store_registry.get_store(store_uri, artifact_uri)
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/tracking/_tracking_service/registry.py:45, in TrackingStoreRegistry.get_store(self, store_uri, artifact_uri)
#      42 from mlflow.tracking._tracking_service import utils
#      44 resolved_store_uri = utils._resolve_tracking_uri(store_uri)
# ---> 45 return self._get_store_with_resolved_uri(resolved_store_uri, artifact_uri)
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/tracking/_tracking_service/registry.py:56, in TrackingStoreRegistry._get_store_with_resolved_uri(self, resolved_store_uri, artifact_uri)
#      54 with _building_store_lock:
#      55     builder = self.get_store_builder(resolved_store_uri)
# ---> 56     return builder(store_uri=resolved_store_uri, artifact_uri=artifact_uri)
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/tracking/_tracking_service/utils.py:140, in _get_file_store(store_uri, **_)
#     137 def _get_file_store(store_uri, **_):
#     138     from mlflow.store.tracking.file_store import FileStore
# --> 140     return FileStore(store_uri, store_uri)
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/store/tracking/file_store.py:234, in FileStore.__init__(self, root_directory, artifact_root_uri)
#     232 # Create root directory if needed
#     233 if not exists(self.root_directory):
# --> 234     self._create_default_experiment()
#     235 # Create trash folder if needed
#     236 if not exists(self.trash_folder):
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/store/tracking/file_store.py:240, in FileStore._create_default_experiment(self)
#     239 def _create_default_experiment(self):
# --> 240     mkdir(self.root_directory)
#     241     self._create_experiment_with_id(
#     242         name=Experiment.DEFAULT_EXPERIMENT_NAME,
#     243         experiment_id=FileStore.DEFAULT_EXPERIMENT_ID,
#     244         artifact_uri=None,
#     245         tags=None,
#     246     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/utils/file_utils.py:210, in mkdir(root, name)
#     208 except OSError as e:
#     209     if e.errno != errno.EEXIST or not os.path.isdir(target):
# --> 210         raise e
#     211 return target
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlflow/utils/file_utils.py:207, in mkdir(root, name)
#     205 target = os.path.join(root, name) if name is not None else root
#     206 try:
# --> 207     os.makedirs(target, exist_ok=True)
#     208 except OSError as e:
#     209     if e.errno != errno.EEXIST or not os.path.isdir(target):
#
# File <frozen os>:215, in makedirs(name, mode, exist_ok)
#
# File <frozen os>:215, in makedirs(name, mode, exist_ok)
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# OSError: [Errno 45] Operation not supported: '/home/ubuntu'
